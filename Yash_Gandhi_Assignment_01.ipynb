# %% [markdown]
# ### **Activity**
# * Open the dataset **ipl_batting** using **Excel** or **Google sheets**
# * Answer the below questions :
# --------------------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# bat : DF FOR BATTING CSV <BR>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 1**
# * For how many **IPL seasons** is the data available for?
# -----------------------------

# %% [markdown]
# <b>
# Splitting match_date column into year,month and date and then finding number of unique years present which correspond to different seasons <br>Answer : 12 seasons <br>
#
# ![image.png](data:image/png;base64,...)
# <BR>
# ![image.png](data:image/png;base64,...)
#
# </b>

# %% [markdown]
# ### **Question 2**
# * For how many **total matches** is the data available for?
# -----------------------------

# %% [markdown]
# <b>Answer : 755 + 1 matches
# for 1 match Date is missing</b><BR>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 3**
# * Which all columns have **missing data**?
# -----------------------------

# %% [markdown]
# <b>Answer <BR>
# match_date column has 20 missing values ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 4**
# * What is the **granularity** of the dataset?
# -----------------------------

# %% [markdown]
# <b>Answer : match_no,match_date contribute together to the granularity of the dataset

# %% [markdown]
# ### **Question 5**
# * List down **entities** present in the dataset
# -----------------------------

# %% [markdown]
# <b> Batsmen,Bowler_name,fielder

# %% [markdown]
# ### **Question 6**
# * List down **measures/metrics** present in the dataset
# -----------------------------

# %% [markdown]
# <B>Answer :<BR> R (RUNS)<BR>B (BALLS)<BR>SR (STRIKE RATE)<BR> FOURS<BR>SIXES<BR>is_fielder

# %% [markdown]
# ### **Question 7**
# * List down **dimensions** present in the dataset
# -----------------------------

# %% [markdown]
# <b>Answer :<BR>
# Batsmen<BR>bowler_name<BR>dismissal_mode<BR>spcial_role<BR>match_date<br>fielder

# %% [markdown]
# ### **Question 8**
# * Create at least 3 **derived metrics** from the dataset
# -----------------------------

# %% [markdown]
# **Answer :**
# <B><BR> Runs_in_Running : Runs scored excluding 4's and 6's
# ![image.png](data:image/png;base64,...)
# <br> is_duck : Out on 0 run
# ![image.png](data:image/png;base64,...)
# <br> Scored_50 : Batsmen hits half century
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 9**
# * Create at least 3 **derived dimensions** using the dataset
# -----------------------------

# %% [markdown]
# **Answer :**
# <b><br> 1. Player_aggression : Classifying the innings of a player as per the Strike rate
# <br>![image.png](data:image/png;base64,...)
# <br><br> 2. time_on_field : Classifying as per the number of balls played i.e duration on field <br>
# ![image.png](data:image/png;base64,...)
# <BR><br>3. player_rating_performance : Rating the innings of a player depending on the number of balls played and strike rate i.e time_on_field and player_aggression <br>
# ![image.png](data:image/png;base64,...)
